# %% [markdown]
# ## HEART Disease project

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("heart-disease.csv")

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1
# 7   0     3       1
# 8   0     3       1
# 9   0     2       1

# %% [markdown]
# The following table shows heart disease information for patients

# %%
df.target.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='target'>

# %% [markdown]
# ![](6-step-ml-framework.png)

# %% [markdown]
# ## Problem Definition
# Predict Heart disease

# %% [markdown]
# ## Data
# This is the data we are using

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 926B-94FB
#
#  Directory of C:\Users\DELL\Desktop\Sample_Project_1
#
# 07/28/2026  11:50 PM    <DIR>          .
# 07/28/2026  10:16 PM    <DIR>          ..
# 07/28/2026  11:44 PM    <DIR>          .ipynb_checkpoints
# 07/28/2026  11:22 PM           332,025 6-step-ml-framework.png
# 07/28/2026  11:05 PM    <DIR>          env
# 07/28/2026  11:50 PM            23,240 example.notebook.ipynb
# 07/28/2026  11:20 PM            11,328 heart-disease.csv
#                3 File(s)        366,593 bytes
#                4 Dir(s)  42,776,743,936 bytes free
