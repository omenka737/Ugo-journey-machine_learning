# %%
import pandas as pd

# %%
## 2 main datatypes
series = pd.Series(["BMW", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = 1-dimensional

# %%
colours = pd.Series(["Red", "Blue", "White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# DataFrame = 2-dimensional
car_data = pd.DataFrame({"Car make": series, "Colour":colours})
car_data
# Out:
#   Car make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
# Import Data 
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#Exporting a DataFrame
car_sales.to_csv("exported-car-sales.csv", index = False)

# %%
export_car_sales=pd.read_csv("exported-car-sales.csv")
export_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe Data

# %%
## Attribute
car_sales.dtypes

##Function
##car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
## Describe function works only on numeria values
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.mean(numeric_only = True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([3000, 4000, 5000])
car_prices.mean()
# Out:
# np.float64(4000.0)

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# np.int64(40)

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Viewing and selecting Data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
## .loc & .iloc
animals = pd.Series(["Cat", "Dog", "Bird", "Panda", "Snake"], index = [0,3,9,8,3])
animals
# Out:
# 0      Cat
# 3      Dog
# 9     Bird
# 8    Panda
# 3    Snake
# dtype: object

# %%
# .loc refers to index
animals.loc[3]
# Out:
# 3      Dog
# 3    Snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'Bird'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# .iloc - it refers to position
animals.iloc[3]
# Out:
# 'Panda'

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
animals.iloc[:3]
# Out:
# 0     Cat
# 3     Dog
# 9    Bird
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.head(4)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales.Make == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales.Make, car_sales.Doors)
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Groupby
car_sales.groupby("Make").mean(numeric_only = True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales.groupby("Colour").get_group("White")
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()
plt.title("Odometer (KM)")
plt.xlabel("Numbers")
plt.ylabel("Mileage")
# Out:
# Text(0, 0.5, 'Mileage')

# %%
car_sales["Odometer (KM)"].hist()
plt.title("Odometer");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace(r'[\$\,]', '', regex=True).astype(float)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales["Price"].dtype
# Out:
# dtype('float64')

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulating Data

# %%
car_sales.Make.str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales.Make = car_sales.Make.str.lower()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing.head()
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing["Odometer"].mean()
# Out:
# np.float64(92302.66666666667)

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
## but this values don't show in the car_sales_missing file, at least not yet, WALK WITH ME

car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
## Column from series
seats_column = pd.Series([5,5,5,5,5])

## New column called seats
car_sales["Seats"] = seats_column 
car_sales

## creating new data from existing data, as in the seats data wasnt part of the original, it was just added using code
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    NaN
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
car_sales.Seats=car_sales.Seats.fillna(5)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    5.0
# 6   honda   Blue          45698      4   7500.0    5.0
# 7   honda   Blue          54738      4   7000.0    5.0
# 8  toyota  White          60000      4   6250.0    5.0
# 9  nissan  White          31600      4   9700.0    5.0

# %%
# Column from python list
fuel_economy = [7.5,9.2, 5.0, 9.6, 8.7, 6.7, 7.8, 3.7, 2.8,5]
car_sales["Fuel per 100 KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM
# 0  toyota  White         150043      4   4000.0    5.0              7.5
# 1   honda    Red          87899      4   5000.0    5.0              9.2
# 2  toyota   Blue          32549      3   7000.0    5.0              5.0
# 3     bmw  Black          11179      5  22000.0    5.0              9.6
# 4  nissan  White         213095      4   3500.0    5.0              8.7
# 5  toyota  Green          99213      4   4500.0    5.0              6.7
# 6   honda   Blue          45698      4   7500.0    5.0              7.8
# 7   honda   Blue          54738      4   7000.0    5.0              3.7
# 8  toyota  White          60000      4   6250.0    5.0              2.8
# 9  nissan  White          31600      4   9700.0    5.0              5.0

# %%
car_sales['Total fuel used (L)'] = car_sales["Odometer (KM)"]/100 * car_sales['Fuel per 100 KM']
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 0  toyota  White         150043      4   4000.0    5.0              7.5
# 1   honda    Red          87899      4   5000.0    5.0              9.2
# 2  toyota   Blue          32549      3   7000.0    5.0              5.0
# 3     bmw  Black          11179      5  22000.0    5.0              9.6
# 4  nissan  White         213095      4   3500.0    5.0              8.7
# 5  toyota  Green          99213      4   4500.0    5.0              6.7
# 6   honda   Blue          45698      4   7500.0    5.0              7.8
# 7   honda   Blue          54738      4   7000.0    5.0              3.7
# 8  toyota  White          60000      4   6250.0    5.0              2.8
# 9  nissan  White          31600      4   9700.0    5.0              5.0
#
#    Total fuel used (L)
# 0            11253.225
# 1             8086.708
# 2             1627.450
# 3             1073.184
# 4            18539.265
# 5             6647.271
# ...

# %%
car_sales["Make"] = car_sales["Make"].str.capitalize()

# %%
car_sales.columns.tolist()
# Out:
# ['Make',
#  'Colour',
#  'Odometer (KM)',
#  'Doors',
#  'Price',
#  'Seats',
#  'Fuel per 100 KM',
#  'Total fuel used (L)']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 0  Toyota  White         150043      4   4000.0    5.0              7.5
# 1   Honda    Red          87899      4   5000.0    5.0              9.2
# 2  Toyota   Blue          32549      3   7000.0    5.0              5.0
# 3     Bmw  Black          11179      5  22000.0    5.0              9.6
# 4  Nissan  White         213095      4   3500.0    5.0              8.7
# 5  Toyota  Green          99213      4   4500.0    5.0              6.7
# 6   Honda   Blue          45698      4   7500.0    5.0              7.8
# 7   Honda   Blue          54738      4   7000.0    5.0              3.7
# 8  Toyota  White          60000      4   6250.0    5.0              2.8
# 9  Nissan  White          31600      4   9700.0    5.0              5.0
#
#    Total fuel used (L)
# 0            11253.225
# 1             8086.708
# 2             1627.450
# 3             1073.184
# 4            18539.265
# 5             6647.271
# ...

# %%
# Create a column from a single value
car_sales["Number of Wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 0  Toyota  White         150043      4   4000.0    5.0              7.5
# 1   Honda    Red          87899      4   5000.0    5.0              9.2
# 2  Toyota   Blue          32549      3   7000.0    5.0              5.0
# 3     Bmw  Black          11179      5  22000.0    5.0              9.6
# 4  Nissan  White         213095      4   3500.0    5.0              8.7
# 5  Toyota  Green          99213      4   4500.0    5.0              6.7
# 6   Honda   Blue          45698      4   7500.0    5.0              7.8
# 7   Honda   Blue          54738      4   7000.0    5.0              3.7
# 8  Toyota  White          60000      4   6250.0    5.0              2.8
# 9  Nissan  White          31600      4   9700.0    5.0              5.0
#
#    Total fuel used (L)  Number of Wheels
# 0            11253.225                 4
# 1             8086.708                 4
# 2             1627.450                 4
# ...

# %%
car_sales["Passed road safety"] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 0  Toyota  White         150043      4   4000.0    5.0              7.5
# 1   Honda    Red          87899      4   5000.0    5.0              9.2
# 2  Toyota   Blue          32549      3   7000.0    5.0              5.0
# 3     Bmw  Black          11179      5  22000.0    5.0              9.6
# 4  Nissan  White         213095      4   3500.0    5.0              8.7
# 5  Toyota  Green          99213      4   4500.0    5.0              6.7
# 6   Honda   Blue          45698      4   7500.0    5.0              7.8
# 7   Honda   Blue          54738      4   7000.0    5.0              3.7
# 8  Toyota  White          60000      4   6250.0    5.0              2.8
# 9  Nissan  White          31600      4   9700.0    5.0              5.0
#
#    Total fuel used (L)  Number of Wheels  Passed road safety
# 0            11253.225                 4                True
# ...

# %%
car_sales=car_sales.drop("Total fuel used (L)", axis = 1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 0  Toyota  White         150043      4   4000.0    5.0              7.5
# 1   Honda    Red          87899      4   5000.0    5.0              9.2
# 2  Toyota   Blue          32549      3   7000.0    5.0              5.0
# 3     Bmw  Black          11179      5  22000.0    5.0              9.6
# 4  Nissan  White         213095      4   3500.0    5.0              8.7
# 5  Toyota  Green          99213      4   4500.0    5.0              6.7
# 6   Honda   Blue          45698      4   7500.0    5.0              7.8
# 7   Honda   Blue          54738      4   7000.0    5.0              3.7
# 8  Toyota  White          60000      4   6250.0    5.0              2.8
# 9  Nissan  White          31600      4   9700.0    5.0              5.0
#
#    Number of Wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# ...

# %%
Engine_Capacity = ["v6","v6","v4","v12","v8","v6","v6","v6","v6","v6"]
car_sales["Engine Capacity"] = Engine_Capacity
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 0  Toyota  White         150043      4   4000.0    5.0              7.5
# 1   Honda    Red          87899      4   5000.0    5.0              9.2
# 2  Toyota   Blue          32549      3   7000.0    5.0              5.0
# 3     Bmw  Black          11179      5  22000.0    5.0              9.6
# 4  Nissan  White         213095      4   3500.0    5.0              8.7
# 5  Toyota  Green          99213      4   4500.0    5.0              6.7
# 6   Honda   Blue          45698      4   7500.0    5.0              7.8
# 7   Honda   Blue          54738      4   7000.0    5.0              3.7
# 8  Toyota  White          60000      4   6250.0    5.0              2.8
# 9  Nissan  White          31600      4   9700.0    5.0              5.0
#
#    Number of Wheels  Passed road safety Engine Capacity
# 0                 4                True              v6
# 1                 4                True              v6
# ...

# %%
car_sales_shuffled = car_sales.sample(frac = 1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 1   Honda    Red          87899      4   5000.0    5.0              9.2
# 6   Honda   Blue          45698      4   7500.0    5.0              7.8
# 9  Nissan  White          31600      4   9700.0    5.0              5.0
# 7   Honda   Blue          54738      4   7000.0    5.0              3.7
# 2  Toyota   Blue          32549      3   7000.0    5.0              5.0
# 8  Toyota  White          60000      4   6250.0    5.0              2.8
# 0  Toyota  White         150043      4   4000.0    5.0              7.5
# 5  Toyota  Green          99213      4   4500.0    5.0              6.7
# 4  Nissan  White         213095      4   3500.0    5.0              8.7
# 3     Bmw  Black          11179      5  22000.0    5.0              9.6
#
#    Number of Wheels  Passed road safety Engine Capacity
# 1                 4                True              v6
# 6                 4                True              v6
# ...

# %%
# Only select 20% of the data
car_sales_shuffled.sample(frac = 0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 3     Bmw  Black          11179      5  22000.0    5.0              9.6
# 2  Toyota   Blue          32549      3   7000.0    5.0              5.0
#
#    Number of Wheels  Passed road safety Engine Capacity
# 3                 4                True             v12
# 2                 4                True              v4

# %%
car_sales_shuffled.reset_index(drop = True)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 0   Honda    Red          87899      4   5000.0    5.0              9.2
# 1   Honda   Blue          45698      4   7500.0    5.0              7.8
# 2  Nissan  White          31600      4   9700.0    5.0              5.0
# 3   Honda   Blue          54738      4   7000.0    5.0              3.7
# 4  Toyota   Blue          32549      3   7000.0    5.0              5.0
# 5  Toyota  White          60000      4   6250.0    5.0              2.8
# 6  Toyota  White         150043      4   4000.0    5.0              7.5
# 7  Toyota  Green          99213      4   4500.0    5.0              6.7
# 8  Nissan  White         213095      4   3500.0    5.0              8.7
# 9     Bmw  Black          11179      5  22000.0    5.0              9.6
#
#    Number of Wheels  Passed road safety Engine Capacity
# 0                 4                True              v6
# 1                 4                True              v6
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 0  Toyota  White         150043      4   4000.0    5.0              7.5
# 1   Honda    Red          87899      4   5000.0    5.0              9.2
# 2  Toyota   Blue          32549      3   7000.0    5.0              5.0
# 3     Bmw  Black          11179      5  22000.0    5.0              9.6
# 4  Nissan  White         213095      4   3500.0    5.0              8.7
# 5  Toyota  Green          99213      4   4500.0    5.0              6.7
# 6   Honda   Blue          45698      4   7500.0    5.0              7.8
# 7   Honda   Blue          54738      4   7000.0    5.0              3.7
# 8  Toyota  White          60000      4   6250.0    5.0              2.8
# 9  Nissan  White          31600      4   9700.0    5.0              5.0
#
#    Number of Wheels  Passed road safety Engine Capacity
# 0                 4                True              v6
# 1                 4                True              v6
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply (lambda x: x /1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 0  Toyota  White      93776.875      4   4000.0    5.0              7.5
# 1   Honda    Red      54936.875      4   5000.0    5.0              9.2
# 2  Toyota   Blue      20343.125      3   7000.0    5.0              5.0
# 3     Bmw  Black       6986.875      5  22000.0    5.0              9.6
# 4  Nissan  White     133184.375      4   3500.0    5.0              8.7
# 5  Toyota  Green      62008.125      4   4500.0    5.0              6.7
# 6   Honda   Blue      28561.250      4   7500.0    5.0              7.8
# 7   Honda   Blue      34211.250      4   7000.0    5.0              3.7
# 8  Toyota  White      37500.000      4   6250.0    5.0              2.8
# 9  Nissan  White      19750.000      4   9700.0    5.0              5.0
#
#    Number of Wheels  Passed road safety Engine Capacity
# 0                 4                True              v6
# 1                 4                True              v6
# ...

# %%
# Try it, run your code
# Search for it
# Try again
# Ask
